# %% [markdown]
# # About
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
#
# ## Head2
#
# - Nullam vulputate neque purus, et egestas ipsum condimentum a.
# - Phasellus placerat ac ante sit amet bibendum.
# - Nullam purus massa, placerat nec sollicitudin vitae, hendrerit vel dolor.
#
# ### Head3
#
# 1. Donec erat magna, rhoncus porttitor dolor quis, pharetra ultrices turpis.
# 2. Phasellus maximus pulvinar lorem a congue. Cras quis accumsan metus.
# 3. Duis faucibus urna eget purus luctus egestas.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.cos(x)

plt.plot(x, y, label='cos(x)')
plt.show()
